# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Cursos_Data_Science/Curso_Machine_Learning_UStanford/workWeek3') # utilizar una ruta absoluta para acceder a los archivos de la carpeta
# !pip install ipympl #esto solo toca en colab una única vez si sale error para que salga el widget de matplotlib
from google.colab import output
output.enable_custom_widget_manager()

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Cargar las imágenes
img1 = Image.open("/content/drive/MyDrive/Cursos_Data_Science/Curso_Machine_Learning_UStanford/workWeek3/images/C1_W3_Overfitting_a.png")
img2 = Image.open("/content/drive/MyDrive/Cursos_Data_Science/Curso_Machine_Learning_UStanford/workWeek3/images/C1_W3_Overfitting_b.png")
img3 = Image.open("/content/drive/MyDrive/Cursos_Data_Science/Curso_Machine_Learning_UStanford/workWeek3/images/C1_W3_Overfitting_c.png")

# Redimensionar las imágenes al 30% de su tamaño original
img1 = img1.resize((int(img1.width * 0.3), int(img1.height * 0.3)))
img2 = img2.resize((int(img2.width * 0.3), int(img2.height * 0.3)))
img3 = img3.resize((int(img3.width * 0.3), int(img3.height * 0.3)))

# Crear la figura y los ejes
fig, axes = plt.subplots(1, 3, figsize=(12, 4))  # 1 fila, 3 columnas, tamaño de la figura ajustado
# Mostrar las imágenes en una fila
axes[0].imshow(img1)
axes[0].axis('off')  # Ocultar los ejes

axes[1].imshow(img2)
axes[1].axis('off')  # Ocultar los ejes

axes[2].imshow(img3)
axes[2].axis('off')  # Ocultar los ejes

# Mostrar la figura
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ungraded Lab:  Overfitting
#
# <img align="left" src="./images/C1_W3_Overfitting_a.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_b.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_c.png"     style=" width:250px; padding: 10px; " >

# %% [markdown]
# ## Goals
# In this lab, you will explore:
# - the situations where overfitting can occur
# - some of the solutions

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from plt_overfit import overfit_example, output
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# # Overfitting
# The week's lecture described situations where overfitting can arise. Run the cell below to generate a plot that will allow you to explore overfitting. There are further instructions below the cell.

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)
# Out:
# Output()
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# In the plot above you can:
# - switch between Regression and Categorization examples
# - add data
# - select the degree of the model
# - fit the model to the data
#
# Here are some things you should try:
# - Fit the data with degree = 1; Note 'underfitting'.
# - Fit the data with degree = 6; Note 'overfitting'
# - tune degree to get the 'best fit'
# - add data:
#     - extreme examples can increase overfitting (assuming they are outliers).
#     - nominal examples can reduce overfitting
# - switch between `Regression` and `Categorical` to try both examples.
#
# To reset the plot, re-run the cell. Click slowly to allow the plot to update before receiving the next click.
#
# Notes on implementations:
# - the 'ideal' curves represent the generator model to which noise was added to achieve the data set
# - 'fit' does not use pure gradient descent to improve speed. These methods can be used on smaller data sets.

# %% [markdown]
# ## Congratulations!
# You have developed some intuition about the causes and solutions to overfitting. In the next lab, you will explore a commonly used solution, Regularization.
